# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("F:\\FYP_DATA\\ml_project\\data\\intermidiate\\cleaned.csv")

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=df['Maximum_Temperature'],y=df['water_Discharge'],order=4,scatter_kws={'color':'blue'})
# Out:
# <Axes: xlabel='Maximum_Temperature', ylabel='water_Discharge'>

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=df['Minimun_Temperature'],y=df['water_Discharge'],order=4,scatter_kws={'color':'blue'})
# Out:
# <Axes: xlabel='Minimun_Temperature', ylabel='water_Discharge'>

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=df['Rainfall'],y=df['water_Discharge'],scatter_kws={'color':'orange'})
# Out:
# <Axes: xlabel='Rainfall', ylabel='water_Discharge'>

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df['Day']=df['Date'].dt.day
df['Month']=df['Date'].dt.month
df['Year']=df['Date'].dt.year

# %%
import matplotlib.pyplot as plt
import calendar

plt.figure(figsize=(12, 6))

for month in df['Month'].unique():
    monthly_data = df[df['Month'] == month]
    plt.scatter(monthly_data['Month'], monthly_data['Rainfall'], label=calendar.month_abbr[int(month)])

# Set x-ticks to month names
plt.xticks(ticks=range(1, 13), labels=calendar.month_abbr[1:13])  # Jan to Dec

plt.xlabel('Month')
plt.ylabel('Rainfall')
plt.title('Monthly rainfall in past  Over 10 Years')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

for month in df['Month'].unique():

    monthly_data = df[df['Month'] == month]
    plt.scatter(monthly_data['Month'], monthly_data['water_Discharge'], label=calendar.month_abbr[int(month)])
plt.xticks(ticks=range(1,13),labels=calendar.month_abbr[1:13])
plt.xlabel('month')
plt.ylabel('water Dichage')
plt.title('Monthly Trends Over 10 year of water discharge')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cbar='coolwarm')
# Out:
# <Axes: >
